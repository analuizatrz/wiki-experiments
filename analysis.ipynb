# %%
import pandas as pd
from utils import read_dataset

dataset = read_dataset()

# %%
dataset.shape
# Out:
# (54834, 197)

# %%
dataset.describe()
# Out:
#              pageid  past_category  actual_category  past_revision.anon  \
# count  5.230000e+02   54834.000000     54834.000000                 0.0
# mean   3.693877e+06       2.559416         2.576412                 NaN
# std    3.832838e+06       1.691049         1.694148                 NaN
# min    4.549200e+04       0.000000         0.000000                 NaN
# 25%    5.899800e+05       1.000000         1.000000                 NaN
# 50%    2.043655e+06       2.000000         2.000000                 NaN
# 75%    4.798551e+06       4.000000         4.000000                 NaN
# max    1.289065e+07       5.000000         5.000000                 NaN
#
#        actual_revision.anon  past_revision.commenthidden  \
# count                   0.0                          0.0
# mean                    NaN                          NaN
# std                     NaN                          NaN
# min                     NaN                          NaN
# ...
